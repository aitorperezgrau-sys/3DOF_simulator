# %%
# necessary imports 
from simulator_3dof.auxiliary.read_class import flight_reader
from simulator_3dof.auxiliary.comparison_functions import axis_comparison

# %%
#--------reading of the values---------

# own simulator
reader_sim = flight_reader("/Users/aitorpg/Documents/LEARNING/3DOF_simulator/tests/validation/rocket3_trajectory_3dof.csv")
t_sim, x_sim, y_sim, z_sim, vx_sim, vy_sim, vz_sim, ax_sim, ay_sim, az_sim = reader_sim.create_lists()

# rocketpy simulator
reader_rpy = flight_reader("/Users/aitorpg/Documents/LEARNING/3DOF_simulator/tests/validation/rocketpy_trajectory_3dof.csv")
t_rpy, x_rpy, y_rpy, z_rpy, vx_rpy, vy_rpy, vz_rpy, ax_rpy, ay_rpy, az_rpy  = reader_rpy.create_lists()


# lists definition
ts_list = [t_sim, t_rpy]
xs_list = [x_sim, x_rpy]
ys_list = [y_sim, y_rpy]
zs_list = [z_sim, z_rpy]
vxs_list = [vx_sim, vx_rpy]
vys_list = [vy_sim, vy_rpy]
vzs_list = [vz_sim, vz_rpy]
axs_list = [ax_sim, ax_rpy]
ays_list = [ay_sim, ay_rpy]
azs_list = [az_sim, az_rpy]
# Out:
# 58.098999999955296
# 41.025657

# %%
# X Axis
axis_comparison(ts_list, xs_list, "x values", "X (m)", ["x simulator", "x RocketPy"])

# %%
# Y Axis
axis_comparison(ts_list, ys_list, "y values", "Y (m)", ["y simulator", "y RocketPy"])

# %%
# Z Axis
axis_comparison(ts_list, zs_list, "z values", "Z (m)", ["z simulator", "z RocketPy"])

# %%
# Vx
axis_comparison(ts_list, vxs_list, "vx values", "Vx (m)", ["Vx simulator", "Vx RocketPy"])

# %%
# Vx
axis_comparison(ts_list, vys_list, "vy values", "Vy (m)", ["Vy simulator", "Vy RocketPy"])

# %%
# Vz
axis_comparison(ts_list, vzs_list, "vz values", "Vz (m)", ["Vz simulator", "Vz RocketPy"])

# %%
# Ax
axis_comparison(ts_list, axs_list, "ax values", "Ax (m)", ["Ax simulator", "Ax RocketPy"])

# %%
# Ay
axis_comparison(ts_list, ays_list, "ay values", "Ay (m)", ["Ay simulator", "Ay RocketPy"])

# %%
# Az
axis_comparison(ts_list, azs_list, "az values", "Az (m)", ["Az simulator", "Az RocketPy"])
